# %% [markdown]
# # RegimeRadar — Exploratory Data Analysis
#
# ## 1. Data Overview
#
# ## 2. SPY Price & Returns
#
# ## 3. VIX Analysis
#
# ## 4. EMV Macro Context
#
# ## 5. Regime Label Distribution
#
# ## 6. Feature Correlations

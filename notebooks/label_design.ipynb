# %% [markdown]
# # RegimeRadar — Regime Label Design
#
# ## 1. Stress Score Components
#
# ## 2. Threshold Sensitivity Analysis
#
# ## 3. Regime Distribution Over Time
#
# ## 4. Smoothing Effect
#
# ## 5. Transition Label Distribution
#
# ## 6. Label Quality Checks
